# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)

# %%
df_train = pd.read_csv('../data/train.csv')

# %%
df_test = pd.read_csv('../data/test.csv')

# %%
 158       42465       0      3
 204       42511      33      4
 261       42568       0      4
 446       42753       0      1
 497       42804       0      5,
# Out:
#   Cell In[36], line 1
#     158       42465       0      3
#               ^
# SyntaxError: invalid syntax

# %%
df_test[df_test['Unnamed: 0'] == 42465 ]
# Out:
#      Unnamed: 0  Term  NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  \
# 158       42465    58      3       2.0          0            0              1
#
#     RevLineCr LowDoc DisbursementDate  Sector ApprovalDate  ApprovalFY  \
# 158         N      Y        30-Sep-96       0     5-Sep-07        2007
#
#           City State BankState DisbursementGross        GrAppv      SBA_Appv  \
# 158  PALO ALTO    CA        CA      $150,000.00   $150,000.00   $135,000.00
#
#      UrbanRural
# 158           0

# %%
df_test[df_test['Unnamed: 0'] == 42511 ]
# Out:
#      Unnamed: 0  Term  NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  \
# 204       42511    61      4       1.0          1            1              1
#
#     RevLineCr LowDoc DisbursementDate  Sector ApprovalDate  ApprovalFY  \
# 204         Y      N        31-Oct-04      33     5-Apr-07        2007
#
#         City State BankState DisbursementGross        GrAppv     SBA_Appv  \
# 204  SALINAS    CA        CA      $105,000.00   $105,000.00   $94,500.00
#
#      UrbanRural
# 204           1

# %%
36715,36728

# %%
43816,76170,80780

# %%
df_train.query("ApprovalDate == '22-Sep-06' and State == 'AZ'")
# Out:
#        Unnamed: 0  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 0               0   163     21       1.0          0            0
# 1960         1960   116     10       1.0          0            0
# 5282         5282   163     20       1.0          0            0
# 35691       35691   282     16       1.0          0            0
# 37185       37185    56     22       1.0          0            0
#
#        FranchiseCode RevLineCr LowDoc DisbursementDate  ...  Sector  \
# 0                  1         N      N        31-Jan-98  ...       0
# 1960               1         N      N        31-Jan-98  ...       0
# 5282               1         N      N        31-Jan-98  ...       0
# 35691              1         N      N        31-Jan-98  ...       0
# 37185              1         N      N        31-Jan-98  ...       0
#
#        ApprovalDate ApprovalFY     City State BankState DisbursementGross  \
# 0         22-Sep-06       2006  PHOENIX    AZ        SD       $80,000.00
# ...
